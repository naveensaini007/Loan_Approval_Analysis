# %%
Loan Approval Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('loan_approval_dataset.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP000001    Male     Yes          0      Graduate            No
# 1    LP000002    Male     Yes          1      Graduate            No
# 2    LP000003  Female     Yes          0      Graduate            No
# 3    LP000004  Female     Yes         3+      Graduate            No
# 4    LP000005    Male     Yes          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP000610    Male     Yes          1      Graduate            No
# 610  LP000611  Female     Yes          0  Not Graduate            No
# 611  LP000612  Female     Yes          1      Graduate            No
# 612  LP000613    Male     Yes          1      Graduate            No
# 613  LP000614    Male      No          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               3654                  0          60               360
# 1               2145                547          40               360
# 2               2394                349         110               360
# 3               7724               2306         250                84
# 4               9330               1159         380               180
# ..               ...                ...         ...               ...
# 609             5270               1770         240               240
# 610             2636                  0          80               360
# 611             5207               3054         150               120
# 612             5732               2313         130               360
# 613             3501                  0         140               360
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0     Semiurban           Y
# 2               0.0     Semiurban           N
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0     Semiurban           Y
# 611             1.0         Urban           Y
# 612             1.0     Semiurban           Y
# 613             1.0         Urban           Y
#
# [614 rows x 13 columns]

# %%
df['TotalIncome'] = df['ApplicantIncome'] + df['CoapplicantIncome']
df.boxplot(column='TotalIncome', by='Loan_Status')
# Out:
# <Axes: title={'center': 'TotalIncome'}, xlabel='Loan_Status'>

# %%
df.groupby('Credit_History')['Loan_Status'].value_counts(normalize=True)
# Out:
# Credit_History  Loan_Status
# 0.0             N              1.000000
# 1.0             Y              0.990421
#                 N              0.009579
# Name: proportion, dtype: float64

# %%
df['LoanAmount'].hist(bins=30)
# Out:
# <Axes: >

# %%
df.groupby('Gender')['Loan_Status'].value_counts(normalize=True).unstack().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>
